# %%
import pandas as pd
import numpy as np
import MarineDNA as md
import plotly.offline as pyo
import plotly.graph_objs as go
import plotly.express as px

# %%
file1 = "../../../Data/Flyer2018_16S_table_counts.tsv"
asvs1 = pd.read_csv(file1, index_col=0, sep="\t")

# %%
num_reps = 100

pca_list =  [md.doPCA(md.ranRelPct(asvs1)) for i in range(num_reps)]

# %% [markdown]
# ### Scores Distribution

# %%
#md.plotScoreDistribution([x["scores"] for x in pca_list])

# %% [markdown]
# ### Loadings Summary

# %%
loadings = [x["loadings"] for x in pca_list]

smry0 = md.loadingSummary(
    loadings, 
    pc = 0, 
    asv_labels = 
    asvs1.transpose().columns.values,
    z_thresh = 3,
    pct_outlier_thresh = 0.95
)

# %% [markdown]
# The positive loading ASVs on the first component

# %%
smry0['positive']
# Out:
#                                   mean_loading  median_loading  mean_rank  \
# 4ebf60eae6a25de1f7fb819ff212141c      0.070806        0.070556    2751.59
# 12a678de1ab697ad0c99cd9cbf46fd90      0.068728        0.068727    2750.91
# c98f01664c8b5c71736c631c6fdb6c80      0.065493        0.065259    2749.18
# 53f8cc55ef2454c8901d55f93e52a65c      0.065089        0.065215    2749.01
#
#                                   median_rank  pct_outlier_IQR  pct_outlier_Z
# 4ebf60eae6a25de1f7fb819ff212141c       2752.0              1.0           1.00
# 12a678de1ab697ad0c99cd9cbf46fd90       2751.0              1.0           1.00
# c98f01664c8b5c71736c631c6fdb6c80       2750.0              1.0           0.99
# 53f8cc55ef2454c8901d55f93e52a65c       2749.0              1.0           1.00

# %% [markdown]
# The negative loading ASVs on the first component

# %%
smry0['negative']
# Out:
#                                   mean_loading  median_loading  mean_rank  \
# 9cdadd8a7359a3163fb31ad06be74e8c     -0.066902       -0.066829       2.76
# aac3fed77594bf011ae74840d1c7d22c     -0.065715       -0.065377       3.68
# b534fa4e71a260de690378f789158219     -0.063852       -0.063413       5.47
# b19779d9c98ed411c9f7a9e57968fe9f     -0.063479       -0.063033       6.06
# 00bce3089aa2589763c7ece522044976     -0.063043       -0.062896       6.52
# 6277bf1227318a8c694c353dd2d03def     -0.061597       -0.061351       8.77
# defcb02ec20f29352cb1b1b267f162a4     -0.059712       -0.059319      12.09
#
#                                   median_rank  pct_outlier_IQR  pct_outlier_Z
# 9cdadd8a7359a3163fb31ad06be74e8c          2.0              1.0           1.00
# aac3fed77594bf011ae74840d1c7d22c          3.0              1.0           1.00
# b534fa4e71a260de690378f789158219          5.0              1.0           1.00
# b19779d9c98ed411c9f7a9e57968fe9f          5.0              1.0           1.00
# 00bce3089aa2589763c7ece522044976          5.0              1.0           1.00
# 6277bf1227318a8c694c353dd2d03def          7.5              1.0           1.00
# defcb02ec20f29352cb1b1b267f162a4         11.0              1.0           0.98

# %% [markdown]
# The first component is defined as a contrast between these two sets of ASVs

# %% [markdown]
# ### Summarize loadings for all components

# %%
smry_all = [
    md.loadingSummary(
        loadings, 
        pc = pc, 
        asv_labels = 
        asvs1.transpose().columns.values,
        z_thresh = 3,
        pct_outlier_thresh = 0.95
    ) for pc in range(len(loadings))
]

# %%
smry_all[3]['positive']
# Out:
#                                   mean_loading  median_loading  mean_rank  \
# 4ebf60eae6a25de1f7fb819ff212141c      0.070806        0.070556    2751.59
# 12a678de1ab697ad0c99cd9cbf46fd90      0.068728        0.068727    2750.91
# c98f01664c8b5c71736c631c6fdb6c80      0.065493        0.065259    2749.18
# 53f8cc55ef2454c8901d55f93e52a65c      0.065089        0.065215    2749.01
#
#                                   median_rank  pct_outlier_IQR  pct_outlier_Z
# 4ebf60eae6a25de1f7fb819ff212141c       2752.0              1.0           1.00
# 12a678de1ab697ad0c99cd9cbf46fd90       2751.0              1.0           1.00
# c98f01664c8b5c71736c631c6fdb6c80       2750.0              1.0           0.99
# 53f8cc55ef2454c8901d55f93e52a65c       2749.0              1.0           1.00

# %%
smry_all[3]['negative']
# Out:
#                                   mean_loading  median_loading  mean_rank  \
# 9cdadd8a7359a3163fb31ad06be74e8c     -0.066902       -0.066829       2.76
# aac3fed77594bf011ae74840d1c7d22c     -0.065715       -0.065377       3.68
# b534fa4e71a260de690378f789158219     -0.063852       -0.063413       5.47
# b19779d9c98ed411c9f7a9e57968fe9f     -0.063479       -0.063033       6.06
# 00bce3089aa2589763c7ece522044976     -0.063043       -0.062896       6.52
# 6277bf1227318a8c694c353dd2d03def     -0.061597       -0.061351       8.77
# defcb02ec20f29352cb1b1b267f162a4     -0.059712       -0.059319      12.09
#
#                                   median_rank  pct_outlier_IQR  pct_outlier_Z
# 9cdadd8a7359a3163fb31ad06be74e8c          2.0              1.0           1.00
# aac3fed77594bf011ae74840d1c7d22c          3.0              1.0           1.00
# b534fa4e71a260de690378f789158219          5.0              1.0           1.00
# b19779d9c98ed411c9f7a9e57968fe9f          5.0              1.0           1.00
# 00bce3089aa2589763c7ece522044976          5.0              1.0           1.00
# 6277bf1227318a8c694c353dd2d03def          7.5              1.0           1.00
# defcb02ec20f29352cb1b1b267f162a4         11.0              1.0           0.98

# %% [markdown]
# This extracts the defining ASVs for the third component from the smry_all list

# %% [markdown]
# ### Loadings heatmap

# %%
# go.Figure(
#     go.Heatmap(
#         y = metrics0['loadings'].index[:-1], 
#         z = metrics0['loadings'].iloc[::-1]
#     ), 
#     go.Layout(autosize = False, width = 1000, height = 600)
# )
