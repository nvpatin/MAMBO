# %% [markdown]
# ## In this notebook, amplicon data of two different marker genes from the same samples will be imported as raw read counts. After modeling ASV occurrences as probability distributions and extracting principal components of both data sets, a Bayesian model will be fit to estimate the parameters of a normal likelihood.

# %% [markdown]
# ### Import all the dependencies

# %%
import os
import pandas as pd
import numpy as np
import subprocess

# %% [markdown]
# ### Move to working directory

# %%
os.chdir('/Users/nastassia.patin/GitHub/NOAA-NCAR-Hackathon/Data')

# %% [markdown]
# ### 01. This section imports the amplicon data sets as raw counts and calls an R script to model the ASV occurrences as probability distributions.

# %% [markdown]
# #### Import amplicon data sheets as pandas dataframes and take a look

# %%
file1 = 'Flyer2018_16S_table_counts.tsv'
file2 = 'Flyer2018_18S_table_counts.tsv'
asvs1 = pd.read_csv(file1, index_col=0, sep='\t')
asvs2 = pd.read_csv(file2, index_col=0, sep='\t')

# %%
asvs1
# Out:
#                                   CN18Fc12_8_eDNA  CN18Fc19_5_eDNA  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef              552             7415
# a900b6678ce86851fb16bfafb87f3326              210             1933
# c8e360969108fa2125a3d56eb4dad24f              145             2089
# 72143fd9e63fe40c1258948d2f0d79c3              130             1830
# 7b6b178fad5599c0e9a734e4fb09fd64              156             1742
# ...                                           ...              ...
# 674933a0d44342a0647f7a5b4591f26e                0                0
# bebe1b9a7e9aaa78172c1208111f4570                0                0
# 0128431733f67d02efad766d717fe6fd                0                0
# 41102a7dd1f4647ba5477c947daabc0e                0                0
# 51440f89c391fb32f9ee895db22bf8f8                0                0
#
#                                   CN18Fc21_6_eDNA  CN18Fc22_6_eDNA  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef             8749             8152
# a900b6678ce86851fb16bfafb87f3326             2808             1967
# c8e360969108fa2125a3d56eb4dad24f             2530             2086
# 72143fd9e63fe40c1258948d2f0d79c3             2516             2178
# 7b6b178fad5599c0e9a734e4fb09fd64             1761             1855
# ...                                           ...              ...
# 674933a0d44342a0647f7a5b4591f26e                0                0
# bebe1b9a7e9aaa78172c1208111f4570                0                0
# 0128431733f67d02efad766d717fe6fd                0                0
# 41102a7dd1f4647ba5477c947daabc0e                0                0
# 51440f89c391fb32f9ee895db22bf8f8                0                0
#
#                                   CN18Fc24_6_eDNA  CN18Fc25_5_eDNA  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef             7124            12422
# a900b6678ce86851fb16bfafb87f3326             1671             4912
# c8e360969108fa2125a3d56eb4dad24f             2343             2395
# 72143fd9e63fe40c1258948d2f0d79c3             2256             3332
# 7b6b178fad5599c0e9a734e4fb09fd64             1812             2467
# ...                                           ...              ...
# 674933a0d44342a0647f7a5b4591f26e                0                1
# bebe1b9a7e9aaa78172c1208111f4570                0                0
# 0128431733f67d02efad766d717fe6fd                0                0
# 41102a7dd1f4647ba5477c947daabc0e                0                0
# 51440f89c391fb32f9ee895db22bf8f8                0                0
#
#                                   CN18Fc27_4_eDNA  CN18Fc29_6_eDNA  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef              215             8080
# a900b6678ce86851fb16bfafb87f3326               57             3688
# c8e360969108fa2125a3d56eb4dad24f              129             1625
# 72143fd9e63fe40c1258948d2f0d79c3               56             2535
# 7b6b178fad5599c0e9a734e4fb09fd64               73             1663
# ...                                           ...              ...
# 674933a0d44342a0647f7a5b4591f26e                0                0
# bebe1b9a7e9aaa78172c1208111f4570                0                0
# 0128431733f67d02efad766d717fe6fd                0                0
# 41102a7dd1f4647ba5477c947daabc0e                0                0
# 51440f89c391fb32f9ee895db22bf8f8                0                0
#
#                                   CN18Fc30_4_eDNA  CN18Fc32_4_eDNA  ...  \
# ASV ID                                                              ...
# 495c1bd1608a1dad54d3e2824ce899ef             8799             2231  ...
# a900b6678ce86851fb16bfafb87f3326             3343             1134  ...
# c8e360969108fa2125a3d56eb4dad24f             1664              639  ...
# 72143fd9e63fe40c1258948d2f0d79c3             2316              629  ...
# 7b6b178fad5599c0e9a734e4fb09fd64             1612              515  ...
# ...                                           ...              ...  ...
# 674933a0d44342a0647f7a5b4591f26e                0                0  ...
# bebe1b9a7e9aaa78172c1208111f4570                0                0  ...
# 0128431733f67d02efad766d717fe6fd                0                0  ...
# 41102a7dd1f4647ba5477c947daabc0e                0                0  ...
# 51440f89c391fb32f9ee895db22bf8f8                0                0  ...
#
#                                   CN18SESPkoa_SC36  CN18SESPkoa_SC37  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef              4324              1339
# a900b6678ce86851fb16bfafb87f3326             21023              8898
# c8e360969108fa2125a3d56eb4dad24f              4830                 9
# 72143fd9e63fe40c1258948d2f0d79c3              4227                83
# 7b6b178fad5599c0e9a734e4fb09fd64              2385                47
# ...                                            ...               ...
# 674933a0d44342a0647f7a5b4591f26e                 0                 0
# bebe1b9a7e9aaa78172c1208111f4570                 0                 0
# 0128431733f67d02efad766d717fe6fd                 0                 0
# 41102a7dd1f4647ba5477c947daabc0e                 1                 0
# 51440f89c391fb32f9ee895db22bf8f8                 1                 0
#
#                                   CN18SESPkoa_SC39  CN18SESPkoa_SC40  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef                95              1554
# a900b6678ce86851fb16bfafb87f3326              1367              8291
# c8e360969108fa2125a3d56eb4dad24f               566                20
# 72143fd9e63fe40c1258948d2f0d79c3               512                75
# 7b6b178fad5599c0e9a734e4fb09fd64               287                45
# ...                                            ...               ...
# 674933a0d44342a0647f7a5b4591f26e                 0                 0
# bebe1b9a7e9aaa78172c1208111f4570                 0                 0
# 0128431733f67d02efad766d717fe6fd                 0                 0
# 41102a7dd1f4647ba5477c947daabc0e                 0                 0
# 51440f89c391fb32f9ee895db22bf8f8                 0                 0
#
#                                   CN18SESPkoa_SC41  CN18SESPkoa_SC42  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef               147              2720
# a900b6678ce86851fb16bfafb87f3326              1112              9881
# c8e360969108fa2125a3d56eb4dad24f               551                60
# 72143fd9e63fe40c1258948d2f0d79c3               497               154
# 7b6b178fad5599c0e9a734e4fb09fd64               520               104
# ...                                            ...               ...
# 674933a0d44342a0647f7a5b4591f26e                 0                 0
# bebe1b9a7e9aaa78172c1208111f4570                 0                 0
# 0128431733f67d02efad766d717fe6fd                 0                 0
# 41102a7dd1f4647ba5477c947daabc0e                 0                 0
# 51440f89c391fb32f9ee895db22bf8f8                 0                 0
#
#                                   CN18SESPkoa_SC44  CN18SESPkoa_SC45  \
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef                21              2015
# a900b6678ce86851fb16bfafb87f3326                60              8726
# c8e360969108fa2125a3d56eb4dad24f                43                22
# 72143fd9e63fe40c1258948d2f0d79c3                48                97
# 7b6b178fad5599c0e9a734e4fb09fd64                50                57
# ...                                            ...               ...
# 674933a0d44342a0647f7a5b4591f26e                 0                 0
# bebe1b9a7e9aaa78172c1208111f4570                 0                 0
# 0128431733f67d02efad766d717fe6fd                 0                 0
# 41102a7dd1f4647ba5477c947daabc0e                 0                 0
# 51440f89c391fb32f9ee895db22bf8f8                 0                 0
#
#                                   CN18SESPkoa_SC47  CN18SESPkoa_SC49
# ASV ID
# 495c1bd1608a1dad54d3e2824ce899ef              1847              1886
# a900b6678ce86851fb16bfafb87f3326              9330              8852
# c8e360969108fa2125a3d56eb4dad24f                28                44
# 72143fd9e63fe40c1258948d2f0d79c3               116                80
# 7b6b178fad5599c0e9a734e4fb09fd64                72                49
# ...                                            ...               ...
# 674933a0d44342a0647f7a5b4591f26e                 0                 0
# bebe1b9a7e9aaa78172c1208111f4570                 0                 0
# 0128431733f67d02efad766d717fe6fd                 0                 0
# 41102a7dd1f4647ba5477c947daabc0e                 0                 0
# 51440f89c391fb32f9ee895db22bf8f8                 0                 0
#
# [2752 rows x 63 columns]

# %%
asvs2
# Out:
#            CN18FESPkoa_SC24  CN18FESPkoa_SC26  CN18FESPkoa_SC29  \
# ASV ID
# ASV_1                    31                 7                 5
# ASV_2                     3                 0                 2
# ASV_3                     0                 0                 2
# ASV_4                     4                 0                 0
# ASV_5                  1220               115               124
# ...                     ...               ...               ...
# ASV_12614                 0                 0                 0
# ASV_12622                 0                 0                 0
# ASV_12628                 0                 0                 0
# ASV_12632                 0                 0                 0
# ASV_12654                 0                 0                 0
#
#            CN18FESPkoa_SC30  CN18FESPkoa_SC31  CN18FESPkoa_SC32  \
# ASV ID
# ASV_1                   587                 1                 4
# ASV_2                     0                 0                 1
# ASV_3                     0                 0                 0
# ASV_4                     2                 4               275
# ASV_5                    93               109                86
# ...                     ...               ...               ...
# ASV_12614                 0                 0                 0
# ASV_12622                 0                 0                 0
# ASV_12628                 0                 0                 0
# ASV_12632                 0                 0                 0
# ASV_12654                 0                 0                 0
#
#            CN18FESPkoa_SC34  CN18FESPkoa_SC37  CN18FESPkoa_SC40  \
# ASV ID
# ASV_1                     3                 5                 0
# ASV_2                     0                 0                 0
# ASV_3                     0                 0                 0
# ASV_4                     3                 4                 0
# ASV_5                   123               165               106
# ...                     ...               ...               ...
# ASV_12614                 0                 0                 0
# ASV_12622                 0                 0                 0
# ASV_12628                 0                 0                 0
# ASV_12632                 0                 0                 0
# ASV_12654                 0                 0                 0
#
#            CN18FESPkoa_SC41  ...  CN18Sc09_2_eDNA  CN18Sc10_2_eDNA  \
# ASV ID                       ...
# ASV_1                     1  ...                7                0
# ASV_2                     6  ...                3                1
# ASV_3                     0  ...               17               12
# ASV_4                     9  ...                5                1
# ASV_5                   190  ...               67               42
# ...                     ...  ...              ...              ...
# ASV_12614                 0  ...                0                0
# ASV_12622                 0  ...                0                0
# ASV_12628                 0  ...                0                0
# ASV_12632                 0  ...                0                0
# ASV_12654                 0  ...                0                0
#
#            CN18Sc14_2_eDNA  CN18Sc14_8_eDNA  CN18Sc15_2_eDNA  CN18Sc15_8_eDNA  \
# ASV ID
# ASV_1                    8                9                4                6
# ASV_2                    0                2                1                0
# ASV_3                   52                2                9                0
# ASV_4                    4                1                3             2091
# ASV_5                  109               90               13             3817
# ...                    ...              ...              ...              ...
# ASV_12614                0                0                0                0
# ASV_12622                0                0                0                0
# ASV_12628                0                0                0                0
# ASV_12632                0                0                0                0
# ASV_12654                0                0                0                0
#
#            CN18Sc18_2_eDNA  CN18Sc18_8_eDNA  CN18Sc27_2_eDNA  CN18Sc27_8_eDNA
# ASV ID
# ASV_1                    7                0                3                2
# ASV_2                    2                0                0                1
# ASV_3                  110                2              418                0
# ASV_4                    2             1268                2                1
# ASV_5                   26              141               19              452
# ...                    ...              ...              ...              ...
# ASV_12614                0                0                0                0
# ASV_12622                0                0                0                0
# ASV_12628                0                0                0                0
# ASV_12632                0                0                0                0
# ASV_12654                0                0                0                0
#
# [7385 rows x 63 columns]

# %% [markdown]
# ### Call the R script to model the ASV count distributions

# %% [markdown]
# #### Function to run R program on input data given the file name

# %%
def call_Rscript_for_amplicon_modeling(path, sample_num, arg1):
    # Use subprocess.Popen to open executable Rscript and extract stdout from 'print' command in R
    with subprocess.Popen(['Rscript', path, '--args', '--vanilla', arg1], 
                          stdout=subprocess.PIPE) as result:
        asvs_freq = result.stdout.read()
    
    # The R output gets imported as "bytes"; need to convert to string
    y = asvs_freq.decode("utf-8")
    y = y.replace(",", "").split()

    # remove the column and row headers
    z = [ x for x in y if "[" not in x ]

    # Convert to numpy array
    array = np.asarray(z)
    # Reshape to original dimensions; number of samples (columns) is second field, 
    # unknown number of ASVs can be supplied with '-1'
    mat = np.reshape(array, (-1, sample_num))

    # Convert to data frame with sample names as columns
    names = np.arange(1, sample_num+1, 1)
    df = pd.DataFrame(mat, columns=names)
    df = df.astype(float)
    return(df)

# %% [markdown]
# #### Define arguments

# %%
path_to_rscript = '/Users/nastassia.patin/GitHub/NOAA-NCAR-Hackathon/ranRelPct_testdata.R'
number_of_samples = 63
data_file_name = 'Flyer2018_18S_table_counts.tsv'

# %%
asvs_modeled = call_Rscript_for_amplicon_modeling(path_to_rscript, 
                                                  number_of_samples, 
                                                  data_file_name)

# %%
asvs_modeled
# Out:
#             1         2         3         4         5         6         7   \
# 0     0.000326  0.000098  0.000022  0.006539  0.000047  0.000024  0.000015
# 1     0.000099  0.000601  0.000013  0.000002  0.000011  0.000001  0.000017
# 2     0.000022  0.000015  0.000046  0.000032  0.004517  0.001787  0.004302
# 3     0.008463  0.000008  0.000002  0.000009  0.000007  0.000043  0.003706
# 4     0.000030  0.000004  0.000002  0.000091  0.000084  0.000116  0.000107
# ...        ...       ...       ...       ...       ...       ...       ...
# 7380  0.000086  0.000061  0.000031  0.000042  0.000003  0.000036  0.000043
# 7381  0.000039  0.000057  0.000186  0.000006  0.000081  0.000002  0.000037
# 7382  0.000044  0.000004  0.000240  0.000243  0.000060  0.000007  0.000104
# 7383  0.000036  0.000012  0.000168  0.000152  0.000048  0.000059  0.000065
# 7384  0.000047  0.000035  0.000013  0.000110  0.000012  0.000118  0.000133
#
#             8         9         10  ...            54            55        56  \
# 0     0.000035  0.000019  0.000005  ...  1.250289e-04  4.816341e-03  0.002022
# 1     0.000028  0.000033  0.000008  ...  8.486141e-06  2.317084e-05  0.000011
# 2     0.004853  0.012081  0.007124  ...  1.831040e-07  1.771935e-05  0.000015
# 3     0.000421  0.000880  0.000187  ...  7.207984e-05  9.017859e-07  0.000035
# 4     0.000250  0.000009  0.000004  ...  3.815073e-06  3.948945e-05  0.000006
# ...        ...       ...       ...  ...           ...           ...       ...
# 7380  0.000003  0.000001  0.000223  ...  5.418093e-05  2.075329e-05  0.000027
# 7381  0.000050  0.000046  0.000094  ...  1.190934e-05  9.087088e-06  0.000008
# 7382  0.000103  0.000041  0.000090  ...  3.781550e-06  1.465126e-05  0.000037
# 7383  0.000019  0.000120  0.000208  ...  1.506344e-05  6.089105e-05  0.000028
# 7384  0.000026  0.000033  0.000004  ...  1.062609e-05  1.368558e-06  0.000013
#
#                 57            58            59        60            61  \
# 0     5.357494e-04  1.723658e-04  1.360648e-04  0.000244  3.602203e-04
# 1     2.392482e-05  5.976047e-03  9.161926e-04  0.001160  1.631451e-03
# 2     3.785156e-05  6.210090e-07  4.238389e-06  0.000762  2.493217e-04
# 3     6.478424e-07  4.930632e-05  5.828804e-07  0.000004  3.158749e-05
# 4     2.693301e-06  7.925460e-06  7.195485e-03  0.001428  1.239574e-03
# ...            ...           ...           ...       ...           ...
# 7380  1.834203e-04  2.261242e-04  1.777061e-05  0.000030  1.211248e-06
# 7381  6.452018e-05  5.106562e-05  7.892379e-05  0.000020  1.871284e-05
# 7382  4.650220e-05  9.661620e-05  4.484945e-05  0.000013  5.265142e-05
# 7383  6.844979e-05  5.281686e-05  3.560823e-05  0.000221  7.063306e-05
# 7384  1.132351e-05  3.466121e-05  1.123122e-05  0.000068  4.016656e-07
#
#             62        63
# 0     0.000016  0.000021
# 1     0.005708  0.000007
# 2     0.000492  0.001192
# 3     0.000017  0.000014
# 4     0.001650  0.004154
# ...        ...       ...
# 7380  0.000007  0.000105
# 7381  0.000004  0.000060
# 7382  0.000041  0.000055
# 7383  0.000032  0.000083
# 7384  0.000010  0.000054
#
# [7385 rows x 63 columns]

# %%
df = []

for file in [file1, file2]:
    asvs = pd.read_csv(file, index_col=0, sep='\t')
    number_of_samples = len(asvs.axes[1])
    asvs_modeled = call_Rscript_for_amplicon_modeling(path_to_rscript,
                                      number_of_samples,
                                      file)
    df.append(asvs_modeled)

# %% [markdown]
# #### Separate the two data frames into the 16S and 18S modeled ASV counts

# %%
df_16S = df[0]
df_18S = df[1]

# %%
df_18S
# Out:
#             1         2         3         4         5         6         7   \
# 0     0.000375  0.000128  0.000043  0.007137  0.000038  0.000020  0.000008
# 1     0.000044  0.000599  0.000053  0.000014  0.000033  0.000024  0.000028
# 2     0.000009  0.000006  0.000017  0.000014  0.004337  0.002258  0.004498
# 3     0.009017  0.000011  0.000015  0.000040  0.000005  0.000013  0.003843
# 4     0.000003  0.000009  0.000002  0.000176  0.000067  0.000093  0.000100
# ...        ...       ...       ...       ...       ...       ...       ...
# 7380  0.000078  0.000212  0.000032  0.000035  0.000027  0.000042  0.000093
# 7381  0.000032  0.000004  0.000006  0.000116  0.000045  0.000084  0.000007
# 7382  0.000027  0.000011  0.000159  0.000006  0.000052  0.000064  0.000005
# 7383  0.000221  0.000007  0.000047  0.000174  0.000010  0.000013  0.000049
# 7384  0.000049  0.000010  0.000010  0.000163  0.000004  0.000055  0.000024
#
#             8         9         10  ...            54            55  \
# 0     0.000037  0.000032  0.000018  ...  9.949565e-05  5.528180e-03
# 1     0.000001  0.000006  0.000001  ...  5.342313e-06  4.089348e-08
# 2     0.003678  0.012918  0.007367  ...  4.107297e-05  1.261468e-05
# 3     0.000426  0.001026  0.000221  ...  1.153947e-04  2.444368e-05
# 4     0.000171  0.000052  0.000007  ...  1.322547e-07  2.814651e-05
# ...        ...       ...       ...  ...           ...           ...
# 7380  0.000005  0.000303  0.000070  ...  1.448302e-05  4.811759e-05
# 7381  0.000028  0.000054  0.000154  ...  7.832301e-05  1.651197e-05
# 7382  0.000040  0.000123  0.000028  ...  2.025876e-05  2.156156e-05
# 7383  0.000037  0.000098  0.000045  ...  7.831795e-06  1.135853e-04
# 7384  0.000016  0.000105  0.000005  ...  1.792846e-06  3.239869e-05
#
#                 56        57        58        59        60        61  \
# 0     2.185097e-03  0.000530  0.000125  0.000128  0.000278  0.000344
# 1     4.474338e-06  0.000031  0.006094  0.001285  0.000969  0.001458
# 2     6.579413e-05  0.000006  0.000008  0.000023  0.000848  0.000322
# 3     5.128178e-05  0.000010  0.000032  0.000028  0.000041  0.000122
# 4     1.061699e-07  0.000011  0.000002  0.007969  0.001392  0.001041
# ...            ...       ...       ...       ...       ...       ...
# 7380  2.796660e-05  0.000009  0.000185  0.000017  0.000046  0.000036
# 7381  3.490699e-06  0.000024  0.000016  0.000112  0.000044  0.000110
# 7382  1.466086e-05  0.000022  0.000227  0.000024  0.000088  0.000037
# 7383  3.033953e-06  0.000132  0.000024  0.000022  0.000139  0.000014
# 7384  4.923662e-05  0.000019  0.000015  0.000021  0.000053  0.000034
#
#             62        63
# 0     0.000021  0.000021
# 1     0.006258  0.000017
# 2     0.000541  0.001131
# 3     0.000011  0.000024
# 4     0.001871  0.003603
# ...        ...       ...
# 7380  0.000006  0.000162
# 7381  0.000011  0.000116
# 7382  0.000002  0.000108
# 7383  0.000019  0.000018
# 7384  0.000021  0.000013
#
# [7385 rows x 63 columns]

# %% [markdown]
# ## 02. Convert data to log-odds and extract principal components

# %%
from sklearn.decomposition import PCA
import seaborn as sns

# %%
df_list = [df_16S, df_18S]

# %%
pcs = []

for df in df_list:
    df = np.log10(df)
    pca = PCA(n_components=10)
    pcs.append(pca.fit_transform(df))

# %% [markdown]
# #### Separate the two data frames

# %%
pcs_16S = pcs[0]
pcs_18S = pcs[1]

# %% [markdown]
# #### Plot 16S PCA

# %%
pc1_values = pcs_16S[:,0]
pc2_values = pcs_16S[:,1]
sns.scatterplot(x=pc1_values, y=pc2_values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Plot 18S PCA

# %%
pc1_values = pcs_18S[:,0]
pc2_values = pcs_18S[:,1]
sns.scatterplot(x=pc1_values, y=pc2_values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 03. Construct Bayesian model
